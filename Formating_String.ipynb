# %%
template='halo, saya %s dari %s'

print(template % ('Lendis Fabri', 'indonesia'))
# Out:
# halo, saya Lendis Fabri dari indonesia

# %%
nama= 'Lendis Fabri'
asal= 'Indonesia'

print(f'perkenalkan {nama} dari {asal}')
# Out:
# perkenalkan Lendis Fabri dari Indonesia

# %% [markdown]
# **memecah string menjadi list dan sebaliknya**

# %%
alamat='surabaya, jawa timur, indonesia'

print(alamat.split())
print(alamat.split(','))
print(alamat.split(', '))

print('🫶🏻'.join(['aku','suka','kamu']))
print('*'.join(alamat.split(',')))
# Out:
# ['surabaya,', 'jawa', 'timur,', 'indonesia']
# ['surabaya', ' jawa timur', ' indonesia']
# ['surabaya', 'jawa timur', 'indonesia']
# aku🫶🏻suka🫶🏻kamu
# surabaya* jawa timur* indonesia

# %% [markdown]
# **mengubah string menjadi case**

# %%
print('halo selamat pagi'.upper())
print('halo selamat siang'.upper())
# Out:
# HALO SELAMAT PAGI
# HALO SELAMAT SIANG

# %%
print('apa kabar?'.lower())
print('lagi dimana?'.lower())
# Out:
# apa kabar?
# lagi dimana?

# %%
print('daun tidak pernah membenci angin'.title())
print('LASKAR PELANGI'.title())
# Out:
# Daun Tidak Pernah Membenci Angin
# Laskar Pelangi

# %%
print('indonesia adalah aku'.swapcase())
print('aKu CiNtA kAmU'.swapcase())
# Out:
# INDONESIA ADALAH AKU
# AkU cInTa KaMu

# %% [markdown]
# **Mencari String**

# %%
angka='12345'

print('Index angka 3:', angka.find('3'))
print('Index angka 45:', angka.find('45'))
print('Index angka 35:', angka.find('35'))
print('Index angka 1:', angka.find('1'))
# Out:
# Index angka 3: 2
# Index angka 45: 3
# Index angka 35: -1
# Index angka 1: 0

# %% [markdown]
# **Mereplace string**

# %%
ibu_kota='Jakarta'

print(ibu_kota.replace('a', 'i'))
print(ibu_kota.replace('kar', '🥹'))
print(ibu_kota.replace('a', ''))
# Out:
# Jikirti
# Ja🥹ta
# Jkrt

# %% [markdown]
# **Menghitung banyak kata**

# %%
paragraf='aku sangat suka dengan ayam apalagi ayam goreng dan ayam geprek'
x=paragraf.count('ayam')

print(f'kata "ayam" muncul sebanyak {x} kali')
# Out:
# kata "ayam" muncul sebanyak 3 kali
